# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.00)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.384468
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** Because there are ten classes. And untrained classifier is close to random classification.

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.052236 analytic: -0.052236, relative error: 8.690512e-07
# numerical: -0.116574 analytic: -0.116574, relative error: 6.659711e-09
# numerical: -0.368136 analytic: -0.368136, relative error: 1.317788e-07
# numerical: -3.526507 analytic: -3.526507, relative error: 4.259583e-09
# numerical: 0.989750 analytic: 0.989749, relative error: 2.436165e-08
# numerical: 0.500257 analytic: 0.500257, relative error: 1.237448e-07
# numerical: 1.420818 analytic: 1.420818, relative error: 2.665946e-08
# numerical: 1.952788 analytic: 1.952788, relative error: 2.793261e-08
# numerical: 0.733459 analytic: 0.733459, relative error: 1.231849e-08
# numerical: 4.739652 analytic: 4.739652, relative error: 1.440163e-08
# numerical: -1.676136 analytic: -1.676136, relative error: 2.914143e-10
# numerical: 0.246483 analytic: 0.246483, relative error: 4.782396e-09
# numerical: 2.556950 analytic: 2.556950, relative error: 1.076136e-08
# numerical: 0.065512 analytic: 0.065512, relative error: 4.595910e-08
# numerical: 0.954442 analytic: 0.954442, relative error: 4.952739e-08
# numerical: 0.818365 analytic: 0.818365, relative error: 2.931020e-08
# numerical: 1.446529 analytic: 1.446529, relative error: 6.925417e-09
# numerical: -0.201103 analytic: -0.201103, relative error: 5.382020e-08
# numerical: 0.680704 analytic: 0.680704, relative error: 6.806116e-08
# numerical: 1.263785 analytic: 1.263785, relative error: 3.025292e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.384468e+00 computed in 0.088779s
# (500, 10)
# vectorized loss: 2.384468e+00 computed in 0.007512s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = np.arange(1e-7, 5e-7, 1e-7)
regularization_strengths = np.arange(2.5e4, 5e4, 5e3)

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr in learning_rates:
    for rs in regularization_strengths:
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=1e-7, reg=2.5e4,
                              num_iters=1500, verbose=True)
        y_train_pred = softmax.predict(X_train)
        y_train_accuracy = np.mean(y_train == y_train_pred)
        y_val_pred = softmax.predict(X_val)
        y_val_accuracy = np.mean(y_val == y_val_pred)
        
        if (y_val_accuracy > best_val):
            best_val = y_val_accuracy
            best_softmax = softmax
        
        results[lr, rs] = (y_train_accuracy, y_val_accuracy)

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 783.256269
# iteration 100 / 1500: loss 287.352797
# iteration 200 / 1500: loss 106.497889
# iteration 300 / 1500: loss 40.245553
# iteration 400 / 1500: loss 16.067161
# iteration 500 / 1500: loss 7.205268
# iteration 600 / 1500: loss 3.984150
# iteration 700 / 1500: loss 2.769495
# iteration 800 / 1500: loss 2.337847
# iteration 900 / 1500: loss 2.183751
# iteration 1000 / 1500: loss 2.101498
# iteration 1100 / 1500: loss 2.044923
# iteration 1200 / 1500: loss 2.093229
# iteration 1300 / 1500: loss 2.048911
# iteration 1400 / 1500: loss 2.110025
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 758.992384
# iteration 100 / 1500: loss 278.946987
# iteration 200 / 1500: loss 103.293376
# iteration 300 / 1500: loss 39.139008
# iteration 400 / 1500: loss 15.717721
# iteration 500 / 1500: loss 7.057607
# iteration 600 / 1500: loss 3.897667
# iteration 700 / 1500: loss 2.773859
# iteration 800 / 1500: loss 2.341354
# iteration 900 / 1500: loss 2.206903
# iteration 1000 / 1500: loss 2.116567
# iteration 1100 / 1500: loss 2.129994
# iteration 1200 / 1500: loss 2.070962
# iteration 1300 / 1500: loss 2.010502
# iteration 1400 / 1500: loss 2.102328
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 783.176017
# iteration 100 / 1500: loss 287.110373
# iteration 200 / 1500: loss 106.316403
# iteration 300 / 1500: loss 40.199347
# iteration 400 / 1500: loss 16.095580
# iteration 500 / 1500: loss 7.185024
# iteration 600 / 1500: loss 3.936526
# iteration 700 / 1500: loss 2.760292
# iteration 800 / 1500: loss 2.339564
# iteration 900 / 1500: loss 2.197410
# iteration 1000 / 1500: loss 2.168708
# iteration 1100 / 1500: loss 2.113845
# iteration 1200 / 1500: loss 2.076240
# iteration 1300 / 1500: loss 2.107762
# iteration 1400 / 1500: loss 2.104250
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 778.051210
# iteration 100 / 1500: loss 285.855718
# iteration 200 / 1500: loss 106.027133
# iteration 300 / 1500: loss 40.181374
# iteration 400 / 1500: loss 15.968982
# iteration 500 / 1500: loss 7.238592
# iteration 600 / 1500: loss 3.919954
# iteration 700 / 1500: loss 2.762809
# iteration 800 / 1500: loss 2.336659
# iteration 900 / 1500: loss 2.188309
# iteration 1000 / 1500: loss 2.143354
# iteration 1100 / 1500: loss 2.126427
# iteration 1200 / 1500: loss 2.086583
# iteration 1300 / 1500: loss 2.060057
# iteration 1400 / 1500: loss 2.094850
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 766.093683
# iteration 100 / 1500: loss 281.297842
# iteration 200 / 1500: loss 104.308239
# iteration 300 / 1500: loss 39.588612
# iteration 400 / 1500: loss 15.802442
# iteration 500 / 1500: loss 7.076597
# iteration 600 / 1500: loss 3.931062
# iteration 700 / 1500: loss 2.790620
# iteration 800 / 1500: loss 2.289449
# iteration 900 / 1500: loss 2.204716
# iteration 1000 / 1500: loss 2.110459
# iteration 1100 / 1500: loss 2.102261
# iteration 1200 / 1500: loss 2.106815
# iteration 1300 / 1500: loss 2.147501
# iteration 1400 / 1500: loss 2.112078
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 770.322038
# iteration 100 / 1500: loss 282.934182
# iteration 200 / 1500: loss 104.834249
# iteration 300 / 1500: loss 39.624687
# iteration 400 / 1500: loss 15.890352
# iteration 500 / 1500: loss 7.134221
# iteration 600 / 1500: loss 3.933415
# iteration 700 / 1500: loss 2.750386
# iteration 800 / 1500: loss 2.406645
# iteration 900 / 1500: loss 2.125776
# iteration 1000 / 1500: loss 2.080969
# iteration 1100 / 1500: loss 2.074533
# iteration 1200 / 1500: loss 2.092761
# iteration 1300 / 1500: loss 2.063582
# iteration 1400 / 1500: loss 2.033880
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 775.668053
# iteration 100 / 1500: loss 285.015989
# iteration 200 / 1500: loss 105.502607
# iteration 300 / 1500: loss 39.980777
# iteration 400 / 1500: loss 15.999064
# iteration 500 / 1500: loss 7.122952
# iteration 600 / 1500: loss 3.959025
# iteration 700 / 1500: loss 2.792982
# iteration 800 / 1500: loss 2.190230
# iteration 900 / 1500: loss 2.141256
# iteration 1000 / 1500: loss 2.141620
# iteration 1100 / 1500: loss 2.102743
# iteration 1200 / 1500: loss 2.147374
# iteration 1300 / 1500: loss 2.140229
# iteration 1400 / 1500: loss 2.044898
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 758.320543
# iteration 100 / 1500: loss 278.278100
# iteration 200 / 1500: loss 103.044704
# iteration 300 / 1500: loss 39.125979
# iteration 400 / 1500: loss 15.652911
# iteration 500 / 1500: loss 7.034057
# iteration 600 / 1500: loss 3.894160
# iteration 700 / 1500: loss 2.748632
# iteration 800 / 1500: loss 2.351630
# iteration 900 / 1500: loss 2.156362
# iteration 1000 / 1500: loss 2.129261
# iteration 1100 / 1500: loss 2.083687
# iteration 1200 / 1500: loss 2.128380
# iteration 1300 / 1500: loss 2.106370
# iteration 1400 / 1500: loss 2.074494
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 771.177307
# iteration 100 / 1500: loss 282.519653
# iteration 200 / 1500: loss 104.642706
# iteration 300 / 1500: loss 39.536241
# iteration 400 / 1500: loss 15.767471
# iteration 500 / 1500: loss 7.082879
# iteration 600 / 1500: loss 3.948222
# iteration 700 / 1500: loss 2.746268
# iteration 800 / 1500: loss 2.322163
# iteration 900 / 1500: loss 2.203239
# iteration 1000 / 1500: loss 2.101530
# iteration 1100 / 1500: loss 2.084086
# iteration 1200 / 1500: loss 2.088754
# iteration 1300 / 1500: loss 2.099538
# iteration 1400 / 1500: loss 2.043765
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 772.530368
# iteration 100 / 1500: loss 283.263148
# iteration 200 / 1500: loss 104.990918
# iteration 300 / 1500: loss 39.738864
# iteration 400 / 1500: loss 15.914059
# iteration 500 / 1500: loss 7.194356
# iteration 600 / 1500: loss 3.941131
# iteration 700 / 1500: loss 2.742002
# iteration 800 / 1500: loss 2.362958
# iteration 900 / 1500: loss 2.125266
# iteration 1000 / 1500: loss 2.101966
# iteration 1100 / 1500: loss 2.081776
# iteration 1200 / 1500: loss 2.077995
# iteration 1300 / 1500: loss 2.057935
# iteration 1400 / 1500: loss 2.100514
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 767.345474
# iteration 100 / 1500: loss 281.928087
# iteration 200 / 1500: loss 104.386249
# iteration 300 / 1500: loss 39.593107
# iteration 400 / 1500: loss 15.763310
# iteration 500 / 1500: loss 7.093903
# iteration 600 / 1500: loss 3.969004
# iteration 700 / 1500: loss 2.749029
# iteration 800 / 1500: loss 2.317311
# iteration 900 / 1500: loss 2.220601
# iteration 1000 / 1500: loss 2.114110
# iteration 1100 / 1500: loss 2.096577
# iteration 1200 / 1500: loss 2.053852
# iteration 1300 / 1500: loss 2.060949
# iteration 1400 / 1500: loss 2.079319
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 762.344261
# iteration 100 / 1500: loss 279.390528
# iteration 200 / 1500: loss 103.552673
# iteration 300 / 1500: loss 39.285068
# iteration 400 / 1500: loss 15.683222
# iteration 500 / 1500: loss 6.996808
# iteration 600 / 1500: loss 3.873666
# iteration 700 / 1500: loss 2.759318
# iteration 800 / 1500: loss 2.250769
# iteration 900 / 1500: loss 2.203981
# iteration 1000 / 1500: loss 2.159098
# iteration 1100 / 1500: loss 2.011113
# iteration 1200 / 1500: loss 2.075079
# iteration 1300 / 1500: loss 2.099179
# iteration 1400 / 1500: loss 2.084588
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 776.715854
# iteration 100 / 1500: loss 285.392540
# iteration 200 / 1500: loss 105.636490
# iteration 300 / 1500: loss 39.971403
# iteration 400 / 1500: loss 15.963277
# iteration 500 / 1500: loss 7.158464
# iteration 600 / 1500: loss 4.020128
# iteration 700 / 1500: loss 2.752156
# iteration 800 / 1500: loss 2.358530
# iteration 900 / 1500: loss 2.178468
# iteration 1000 / 1500: loss 2.109572
# iteration 1100 / 1500: loss 2.085821
# iteration 1200 / 1500: loss 2.098305
# iteration 1300 / 1500: loss 2.045139
# iteration 1400 / 1500: loss 2.080870
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 769.173253
# iteration 100 / 1500: loss 282.471156
# iteration 200 / 1500: loss 104.721507
# iteration 300 / 1500: loss 39.634792
# iteration 400 / 1500: loss 15.875976
# iteration 500 / 1500: loss 7.115223
# iteration 600 / 1500: loss 3.970354
# iteration 700 / 1500: loss 2.711548
# iteration 800 / 1500: loss 2.326776
# iteration 900 / 1500: loss 2.149918
# iteration 1000 / 1500: loss 2.077506
# iteration 1100 / 1500: loss 2.048872
# iteration 1200 / 1500: loss 2.087446
# iteration 1300 / 1500: loss 2.040580
# iteration 1400 / 1500: loss 2.077704
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 770.926939
# iteration 100 / 1500: loss 282.983555
# iteration 200 / 1500: loss 104.956820
# iteration 300 / 1500: loss 39.732027
# iteration 400 / 1500: loss 15.844247
# iteration 500 / 1500: loss 7.063011
# iteration 600 / 1500: loss 3.921288
# iteration 700 / 1500: loss 2.784822
# iteration 800 / 1500: loss 2.341856
# iteration 900 / 1500: loss 2.191260
# iteration 1000 / 1500: loss 2.129375
# iteration 1100 / 1500: loss 2.036215
# iteration 1200 / 1500: loss 2.054368
# iteration 1300 / 1500: loss 2.058462
# iteration 1400 / 1500: loss 2.109218
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 771.228221
# iteration 100 / 1500: loss 283.131746
# iteration 200 / 1500: loss 104.943558
# iteration 300 / 1500: loss 39.757263
# iteration 400 / 1500: loss 15.854112
# iteration 500 / 1500: loss 7.126708
# iteration 600 / 1500: loss 3.864648
# iteration 700 / 1500: loss 2.787119
# iteration 800 / 1500: loss 2.274768
# iteration 900 / 1500: loss 2.115177
# iteration 1000 / 1500: loss 2.137948
# iteration 1100 / 1500: loss 2.071570
# iteration 1200 / 1500: loss 2.142396
# iteration 1300 / 1500: loss 2.065515
# iteration 1400 / 1500: loss 2.101717
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 780.833467
# iteration 100 / 1500: loss 286.882476
# iteration 200 / 1500: loss 106.212508
# iteration 300 / 1500: loss 40.287044
# iteration 400 / 1500: loss 16.052631
# iteration 500 / 1500: loss 7.179058
# iteration 600 / 1500: loss 3.987722
# iteration 700 / 1500: loss 2.799209
# iteration 800 / 1500: loss 2.346257
# iteration 900 / 1500: loss 2.212038
# iteration 1000 / 1500: loss 2.144293
# iteration 1100 / 1500: loss 2.103007
# iteration 1200 / 1500: loss 2.089141
# iteration 1300 / 1500: loss 2.044003
# iteration 1400 / 1500: loss 2.067383
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 772.776854
# iteration 100 / 1500: loss 283.452548
# iteration 200 / 1500: loss 104.984005
# iteration 300 / 1500: loss 39.842692
# iteration 400 / 1500: loss 15.868031
# iteration 500 / 1500: loss 7.176317
# iteration 600 / 1500: loss 3.974696
# iteration 700 / 1500: loss 2.731926
# iteration 800 / 1500: loss 2.299344
# iteration 900 / 1500: loss 2.095730
# iteration 1000 / 1500: loss 2.067648
# iteration 1100 / 1500: loss 2.116838
# iteration 1200 / 1500: loss 2.062343
# iteration 1300 / 1500: loss 2.136259
# iteration 1400 / 1500: loss 2.049778
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 770.887081
# iteration 100 / 1500: loss 283.226621
# iteration 200 / 1500: loss 104.929257
# iteration 300 / 1500: loss 39.723437
# iteration 400 / 1500: loss 15.889671
# iteration 500 / 1500: loss 7.123056
# iteration 600 / 1500: loss 3.880808
# iteration 700 / 1500: loss 2.812300
# iteration 800 / 1500: loss 2.333151
# iteration 900 / 1500: loss 2.214857
# iteration 1000 / 1500: loss 2.160671
# iteration 1100 / 1500: loss 2.151777
# iteration 1200 / 1500: loss 2.111651
# iteration 1300 / 1500: loss 2.042046
# iteration 1400 / 1500: loss 2.100557
# (49000,)
# (1000,)
# iteration 0 / 1500: loss 779.813224
# iteration 100 / 1500: loss 286.703705
# iteration 200 / 1500: loss 106.087016
# iteration 300 / 1500: loss 40.204738
# iteration 400 / 1500: loss 16.083767
# iteration 500 / 1500: loss 7.175303
# iteration 600 / 1500: loss 3.919157
# iteration 700 / 1500: loss 2.755708
# iteration 800 / 1500: loss 2.401649
# iteration 900 / 1500: loss 2.193102
# iteration 1000 / 1500: loss 2.114335
# iteration 1100 / 1500: loss 2.105136
# iteration 1200 / 1500: loss 2.098898
# iteration 1300 / 1500: loss 2.096251
# iteration 1400 / 1500: loss 2.100716
# (49000,)
# (1000,)
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.328327 val accuracy: 0.341000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.332347 val accuracy: 0.355000
# lr 1.000000e-07 reg 3.500000e+04 train accuracy: 0.333327 val accuracy: 0.352000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.327102 val accuracy: 0.336000
# lr 1.000000e-07 reg 4.500000e+04 train accuracy: 0.326082 val accuracy: 0.341000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.332061 val accuracy: 0.345000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.329224 val accuracy: 0.337000
# lr 2.000000e-07 reg 3.500000e+04 train accuracy: 0.331755 val accuracy: 0.347000
# lr 2.000000e-07 reg 4.000000e+04 train accuracy: 0.327898 val accuracy: 0.345000
# lr 2.000000e-07 reg 4.500000e+04 train accuracy: 0.328735 val accuracy: 0.333000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.328163 val accuracy: 0.341000
# lr 3.000000e-07 reg 3.000000e+04 train accuracy: 0.329694 val accuracy: 0.338000
# lr 3.000000e-07 reg 3.500000e+04 train accuracy: 0.320082 val accuracy: 0.341000
# lr 3.000000e-07 reg 4.000000e+04 train accuracy: 0.322816 val accuracy: 0.343000
# lr 3.000000e-07 reg 4.500000e+04 train accuracy: 0.326735 val accuracy: 0.342000
# lr 4.000000e-07 reg 2.500000e+04 train accuracy: 0.323367 val accuracy: 0.342000
# lr 4.000000e-07 reg 3.000000e+04 train accuracy: 0.330755 val accuracy: 0.335000
# lr 4.000000e-07 reg 3.500000e+04 train accuracy: 0.328429 val accuracy: 0.340000
# lr 4.000000e-07 reg 4.000000e+04 train accuracy: 0.330490 val accuracy: 0.348000
# lr 4.000000e-07 reg 4.500000e+04 train accuracy: 0.326306 val accuracy: 0.342000
# best validation accuracy achieved during cross-validation: 0.355000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# (1000,)
# softmax on raw pixels final test set accuracy: 0.347000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
